# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ### Load dataset

# %%
# Load dataset from Kaggle
dataset_path = kagglehub.dataset_download("elvinrustam/books-dataset")

# Print the path where files are stored
print("Dataset downloaded to:", dataset_path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.10).
# Dataset downloaded to: C:\Users\afraa\.cache\kagglehub\datasets\elvinrustam\books-dataset\versions\3

# %%
# Find the CSV file in the downloaded directory
csv_file = [f for f in os.listdir(dataset_path) if f.endswith(".csv")][0]

# Load the dataset
df = pd.read_csv(os.path.join(dataset_path, csv_file))

# Display the first few rows
df.head()
# Out:
#                                                Title  \
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide
#
#                     Authors Description              Category  \
# 0          By Colton, Larry         NaN     History , General
# 1        By Grumbach, Doris         NaN     Fiction , General
# 2  By Piscatella, Joseph C.         NaN   Cooking , Reference
# 3         By Davis, Paul D.         NaN                   NaN
# 4          By Spangler, Amy         NaN                   NaN
#
#           Publisher                 Publish Date                    Price
# 0         Doubleday      Friday, January 1, 1993  Price Starting at $8.79
# 1  Putnam Pub Group        Sunday, March 1, 1981  Price Starting at $4.99
# 2    Workman Pub Co  Thursday, September 1, 1983  Price Starting at $4.99
# 3     Natl Pr Books        Monday, April 1, 1991  Price Starting at $4.99
# 4      Amy Spangler   Saturday, February 1, 1997  Price Starting at $5.32

# %% [markdown]
# ### Inspect data

# %%
df.shape
# Out:
# (103082, 7)

# %%
df.describe()
# Out:
#                  Title Authors  \
# count           103082  103082
# unique           97818   63580
# top     The Nutcracker      By
# freq                12    1043
#
#                                               Description            Category  \
# count                                               70213               76912
# unique                                              68831                3106
# top     For Ingest Only - Data needs to be cleaned up ...   Fiction , General
# freq                                                   30                2549
#
#                Publisher               Publish Date                    Price
# count             103074                     103082                   103082
# unique             13029                        956                     1387
# top     Simon & Schuster  Thursday, January 1, 2004  Price Starting at $5.29
# freq                1521                        868                    41876

# %% [markdown]
# ### Handle missing data

# %%
df.isnull().sum()
# Out:
# Title               0
# Authors             0
# Description     32869
# Category        26170
# Publisher           8
# Publish Date        0
# Price               0
# dtype: int64

# %% [markdown]
# ### Checking for duplicates

# %%
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 8

# %%
#Print duplicate occurances
df[df.duplicated(keep=False)]
# Out:
#                                                    Title  \
# 21438                                   Love You Forever
# 26545  Organized to Be the Best!: New Timesaving Ways...
# 27034                                        The Germans
# 27624  Organized to Be the Best!: New Timesaving Ways...
# 30120                                   Love You Forever
# 40770                                        The Prophet
# 50350                                        The Prophet
# 67074              The Secret (Seasons of Grace, Book 1)
# 67420                                        The Germans
# 69075              The Secret (Seasons of Grace, Book 1)
# 78779                                      The Last Song
# 83126  ACSM's Guidelines for Exercise Testing and Pre...
# 85329  ACSM's Guidelines for Exercise Testing and Pre...
# 88713                                      The Last Song
# 92924                Sidney Sheldon's After the Darkness
# 97094                Sidney Sheldon's After the Darkness
#
#                                             Authors  \
# 21438       By Munsch, Robert N. and McGraw, Sheila
# 26545                              By Silver, Susan
# 27034                           By Craig, Gordon A.
# 27624                              By Silver, Susan
# 30120       By Munsch, Robert N. and McGraw, Sheila
# 40770                              By Kahlil Gibran
# 50350                              By Kahlil Gibran
# 67074                             By Lewis, Beverly
# 67420                           By Craig, Gordon A.
# 69075                             By Lewis, Beverly
# 78779                           By Sparks, Nicholas
# 83126  By American College of Sports Medicine (COR)
# 85329  By American College of Sports Medicine (COR)
# 88713                           By Sparks, Nicholas
# 92924                            By Bagshawe, Tilly
# 97094                            By Bagshawe, Tilly
#
#                                              Description  \
# 21438  A young woman holds her newborn sonAnd looks a...
# 26545  Provides a practical approach to time manageme...
# 27034                                                NaN
# 27624  Provides a practical approach to time manageme...
# 30120  A young woman holds her newborn sonAnd looks a...
# 40770                                                NaN
# 50350                                                NaN
# 67074  In the seemingly ordinary Amish home of Grace ...
# 67420                                                NaN
# 69075  In the seemingly ordinary Amish home of Grace ...
# 78779  From the author of A Walk to Remember comes a ...
# 83126  The single most internationally read and refer...
# 85329  The single most internationally read and refer...
# 88713  From the author of A Walk to Remember comes a ...
# 92924  Author Tillie Bagshawe brilliantly recaptured ...
# 97094  Author Tillie Bagshawe brilliantly recaptured ...
#
#                                                 Category  \
# 21438   Juvenile Fiction , Social Themes , Emotions &...
# 26545                     Business & Economics , General
# 27034                                                NaN
# 27624                     Business & Economics , General
# 30120   Juvenile Fiction , Social Themes , Emotions &...
# 40770                                                NaN
# 50350                                                NaN
# 67074                      Fiction , Christian , General
# 67420                                                NaN
# 69075                      Fiction , Christian , General
# 78779                    Fiction , Family Life , General
# 83126                          Medical , Sports Medicine
# 85329                          Medical , Sports Medicine
# 88713                    Fiction , Family Life , General
# 92924                     Fiction , Thrillers , Suspense
# 97094                     Fiction , Thrillers , Suspense
#
#                            Publisher                 Publish Date  \
# 21438                  Firefly Books    Friday, September 1, 1995
# 26545                 Adams Hall Pub      Sunday, October 1, 1995
# 27034                          Plume        Friday, April 1, 1983
# 27624                 Adams Hall Pub      Sunday, October 1, 1995
# 30120                  Firefly Books    Friday, September 1, 1995
# 40770                         Senate   Wednesday, January 1, 2003
# 50350                         Senate   Wednesday, January 1, 2003
# 67074       Bethany House Publishers        Sunday, March 1, 2009
# 67420                          Plume        Friday, April 1, 1983
# 69075       Bethany House Publishers        Sunday, March 1, 2009
# 78779       Grand Central Publishing     Monday, February 1, 2010
# 83126  Lippincott Williams & Wilkins     Sunday, February 1, 2009
# 85329  Lippincott Williams & Wilkins     Sunday, February 1, 2009
# 88713       Grand Central Publishing     Monday, February 1, 2010
# 92924                         Harper  Wednesday, December 1, 2010
# 97094                         Harper  Wednesday, December 1, 2010
#
#                          Price
# 21438  Price Starting at $4.99
# 26545  Price Starting at $5.29
# 27034  Price Starting at $5.29
# 27624  Price Starting at $5.29
# 30120  Price Starting at $4.99
# 40770  Price Starting at $5.29
# 50350  Price Starting at $5.29
# 67074  Price Starting at $5.29
# 67420  Price Starting at $5.29
# 69075  Price Starting at $5.29
# 78779  Price Starting at $5.29
# 83126  Price Starting at $5.29
# 85329  Price Starting at $5.29
# 88713  Price Starting at $5.29
# 92924  Price Starting at $5.29
# 97094  Price Starting at $5.29

# %%
#Print duplicate rows to be removed
df[df.duplicated()]
# Out:
#                                                    Title  \
# 27624  Organized to Be the Best!: New Timesaving Ways...
# 30120                                   Love You Forever
# 50350                                        The Prophet
# 67420                                        The Germans
# 69075              The Secret (Seasons of Grace, Book 1)
# 85329  ACSM's Guidelines for Exercise Testing and Pre...
# 88713                                      The Last Song
# 97094                Sidney Sheldon's After the Darkness
#
#                                             Authors  \
# 27624                              By Silver, Susan
# 30120       By Munsch, Robert N. and McGraw, Sheila
# 50350                              By Kahlil Gibran
# 67420                           By Craig, Gordon A.
# 69075                             By Lewis, Beverly
# 85329  By American College of Sports Medicine (COR)
# 88713                           By Sparks, Nicholas
# 97094                            By Bagshawe, Tilly
#
#                                              Description  \
# 27624  Provides a practical approach to time manageme...
# 30120  A young woman holds her newborn sonAnd looks a...
# 50350                                                NaN
# 67420                                                NaN
# 69075  In the seemingly ordinary Amish home of Grace ...
# 85329  The single most internationally read and refer...
# 88713  From the author of A Walk to Remember comes a ...
# 97094  Author Tillie Bagshawe brilliantly recaptured ...
#
#                                                 Category  \
# 27624                     Business & Economics , General
# 30120   Juvenile Fiction , Social Themes , Emotions &...
# 50350                                                NaN
# 67420                                                NaN
# 69075                      Fiction , Christian , General
# 85329                          Medical , Sports Medicine
# 88713                    Fiction , Family Life , General
# 97094                     Fiction , Thrillers , Suspense
#
#                            Publisher                 Publish Date  \
# 27624                 Adams Hall Pub      Sunday, October 1, 1995
# 30120                  Firefly Books    Friday, September 1, 1995
# 50350                         Senate   Wednesday, January 1, 2003
# 67420                          Plume        Friday, April 1, 1983
# 69075       Bethany House Publishers        Sunday, March 1, 2009
# 85329  Lippincott Williams & Wilkins     Sunday, February 1, 2009
# 88713       Grand Central Publishing     Monday, February 1, 2010
# 97094                         Harper  Wednesday, December 1, 2010
#
#                          Price
# 27624  Price Starting at $5.29
# 30120  Price Starting at $4.99
# 50350  Price Starting at $5.29
# 67420  Price Starting at $5.29
# 69075  Price Starting at $5.29
# 85329  Price Starting at $5.29
# 88713  Price Starting at $5.29
# 97094  Price Starting at $5.29

# %%
#Drop duplicates
df.drop_duplicates(inplace=True)

# %%
#Check data types
df.dtypes
# Out:
# Title           object
# Authors         object
# Description     object
# Category        object
# Publisher       object
# Publish Date    object
# Price           object
# dtype: object

# %% [markdown]
# ### Drop irrelevant columns

# %%
df = df.drop(['Publish Date', 'Price'], axis=1)
df.head(5)
# Out:
#                                                Title  \
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide
#
#                     Authors Description              Category  \
# 0          By Colton, Larry         NaN     History , General
# 1        By Grumbach, Doris         NaN     Fiction , General
# 2  By Piscatella, Joseph C.         NaN   Cooking , Reference
# 3         By Davis, Paul D.         NaN                   NaN
# 4          By Spangler, Amy         NaN                   NaN
#
#           Publisher
# 0         Doubleday
# 1  Putnam Pub Group
# 2    Workman Pub Co
# 3     Natl Pr Books
# 4      Amy Spangler

# %%
# Select the first 10000 entries
df_subset = df.head(10000)

# %%
# Chage to file location 

df_subset.to_csv("E:/Projects/Book_Recommender/book_data.csv", index=False)
